# %%
# !pip install pandas matplotlib openpyxl

# %%
#R1 Quelles sont les nœuds ainsi que leurs  ́etiquettes et proprietes selectionńees
#qui font partie du reified node 1001?
?[associated_node, associated_label, associated_prop] :=
*n_composed_of_node_label[id_rn, associated_node, associated_label],
*n_composed_of_node_prop[id_rn, associated_node, associated_prop],
id_rn = 1011

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données
file_path = "CozoRPG_R1.xlsx"
# file_path = "CozoRPG_R1_2.xlsx"
df = pd.read_excel(file_path)

# Créer la figure
plt.figure(figsize=(14, 6))

# Tracer uniquement la courbe CozoRPG
plt.plot(df['DS_size'], df['CozoRPG'], marker='o', color='green', label='CozoRPG')

# Ajouter les titres et les axes
plt.title("Évolution de CozoRPG", fontsize=16)
plt.xlabel("Taille des données (DS_size)", fontsize=12)
plt.ylabel("Temps d'exécution (ms)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Sauvegarder le graphique
plt.savefig("CozoRPG_R1.png")
plt.show()

# %%
#R2  Recherche d'un élément contenu dans un nœud réifié selon des critères :

#Retourner le nom et l'@ ip de la personne responsable à l'interaction numéro 1004

?[FirstName, LastName, ip] := 
*node_prop[id_n, "lastName", LastName],
*node_prop[id_n, "locationIP", ip],
*node_label[id_n, "person"],
*n_composed_of_node[id_rn, id_n],
id_rn=1004

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données
file_path = "CozoRPG_R2.xlsx"
df = pd.read_excel(file_path)

# Créer la figure
plt.figure(figsize=(14, 6))

# Tracer uniquement la courbe CozoRPG
plt.plot(df['DS_size'], df['CozoRPG'], marker='o', color='purple', label='CozoRPG')

# Ajouter les titres et les axes
plt.title("Évolution de CozoRPG", fontsize=16)
plt.xlabel("Taille des données (DS_size)", fontsize=12)
plt.ylabel("Temps d'exécution (ms)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Sauvegarder le graphique
plt.savefig("CozoRPG_R2.png")
plt.show()

# %%
#R3 récursivité : Traverser deux niveaux d'abstraction
# Retourner les dates de créations de tous les commentaires aimés au niveau de l'ensemble
# des interaction inclues dans le useractivity 1014

?[cmt, CreationDate] := 
*node_prop[cmt, "creationDate", CreationDate],
*node_label[cmt, "comment"],
*n_composed_of_node[inter, cmt],
*n_composed_of_node[id_rn, inter], 
id_rn=1014

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données
file_path = "CozoRPG_R3.xlsx"

df = pd.read_excel(file_path)

# Créer la figure
plt.figure(figsize=(14, 6))

# Tracer uniquement la courbe CozoRPG
plt.plot(df['DS_size'], df['CozoRPG'], marker='o', color='orange', label='CozoRPG')

# Ajouter les titres et les axes
plt.title("Évolution de CozoRPG", fontsize=16)
plt.xlabel("Taille des données (DS_size)", fontsize=12)
plt.ylabel("Temps d'exécution (ms)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Sauvegarder le graphique
plt.savefig("CozoRPG_R3.png")
plt.show()

# %%
#R4 Quelles sont les nœuds ainsi que leurs étiquettes et propriétés sélectionnées
#qui font partie du reified edge 5001 ?

?[associated_node, associated_label, associated_prop] :=
*e_composed_of_node_label[id_re, associated_node, associated_label],
*e_composed_of_node_prop[id_re, associated_node, associated_prop],
id_re = 5001

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données
#file_path = "CozoRPG_R3.xlsx"
file_path = "CozoRPG_R4.xlsx"
df = pd.read_excel(file_path)

# Créer la figure
plt.figure(figsize=(14, 6))

# Tracer uniquement la courbe CozoRPG
plt.plot(df['DS_size'], df['CozoRPG'], marker='o', color='blue', label='CozoRPG')

# Ajouter les titres et les axes
plt.title("Évolution de CozoRPG", fontsize=16)
plt.xlabel("Taille des données (DS_size)", fontsize=12)
plt.ylabel("Temps d'exécution (ms)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Sauvegarder le graphique
plt.savefig("CozoRPG_R4.png")
plt.show()

# %%
#R5 Recherche dans une arête réifiée selon les critères de ses éléments 

#Quelles sont les arêtes de type replyOfHistory qui contiennent les commentaires 
#d'une publication de longueur plus de 200 ?

?[reified_edge, post, creationDate] := 
*edge_label[reified_edge, "replyOfHistory"],
*e_composed_of_node[reified_edge, post],
*node_label[post, "post"],
*node_prop[post, "length", len], 
len > 200 #it compares a string

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données

file_path = "CozoRPG_R5.xlsx"
df = pd.read_excel(file_path)

# Créer la figure
plt.figure(figsize=(14, 6))

# Tracer uniquement la courbe CozoRPG
plt.plot(df['DS_size'], df['CozoRPG'], marker='o', color='cyan', label='CozoRPG')

# Ajouter les titres et les axes
plt.title("Évolution de CozoRPG", fontsize=16)
plt.xlabel("Taille des données (DS_size)", fontsize=12)
plt.ylabel("Temps d'exécution (ms)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Sauvegarder le graphique
plt.savefig("CozoRPG_R5.png")
plt.show()

# %%
#R6 Recursion : Recherche dans une arête doublement réifiée

#Au niveau de l'arête doublement réifiée 5007, retourner la publication ayant des 
#commentaires incluent dans ReplyOfHistory ainsi que sa longueur.


?[id_post, length] := 
*e_composed_of_edge[id_re, id_e],
*edge_label[id_e,"replyOfHistory"], 
*e_composed_of_node[id_e, id_post],
*node_label[id_post, "post"],
*node_prop[id_post, "length", length], id_re=5007

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données

file_path = "CozoRPG_R6.xlsx"
df = pd.read_excel(file_path)

# Créer la figure
plt.figure(figsize=(14, 6))

# Tracer uniquement la courbe CozoRPG
plt.plot(df['DS_size'], df['CozoRPG'], marker='o', color='brown', label='CozoRPG')

# Ajouter les titres et les axes
plt.title("Évolution de CozoRPG", fontsize=16)
plt.xlabel("Taille des données (DS_size)", fontsize=12)
plt.ylabel("Temps d'exécution (ms)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Sauvegarder le graphique
plt.savefig("CozoRPG_R6.png")
plt.show()
