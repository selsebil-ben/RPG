# %%
# !pip install pandas matplotlib openpyxl

# %%
#R1 : retourner les id des taggedComment dont le name du noeud tag qui le compose égale à "Tech"

?[taggedId] :=
  *reified_node[taggedId],
  *n_composed_of_node[taggedId, tagNode],
  *node_label[tagNode, "tag"],
  *node_prop[tagNode, "name", "Tech"]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données

file_path = "CozoRPG_RN.xlsx"
df = pd.read_excel(file_path)

# Créer la figure
plt.figure(figsize=(14, 6))

# Tracer uniquement la courbe CozoRPG
plt.plot(df['#reified nodes'], df['CozoRPG'], marker='o', color='green', label='CozoRPG')

# Ajouter les titres et les axes
plt.title("Évolution de CozoRPG", fontsize=16)
plt.xlabel("#reified nodes", fontsize=12)
plt.ylabel("Temps d'exécution (ms)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Sauvegarder le graphique
plt.savefig("CozoRPG_RN.png")
plt.show()

# %%
#R2  : Retourner les employés qui travailleent chez Apple depuis 2000


?[personId] :=
 *edge_label[reId, "hasEmployee"],
  *e_composed_of_node[reId, personId],
  *node_label[personId, "person"],
  *e_composed_of_node[reId, orgId],
  *node_label[orgId, "organisation"],
  *node_prop[orgId, "name", "Apple"],
  *e_composed_of_edge[reId, workId],
  *edge_label[workId, "workAt"],
  *edge_prop[workId, "workFrom", "2000"]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Charger les données
file_path = "CozoRPG_RE.xlsx"
df = pd.read_excel(file_path)

# Convertir la colonne '#reified edges' en chaîne de caractères
df['#reified edges'] = df['#reified edges'].astype(str)

# Créer la figure
plt.figure(figsize=(14, 6))

# Tracer uniquement la courbe CozoRPG
plt.plot(df['#reified edges'], df['CozoRPG'], marker='o', color='purple', label='CozoRPG')

# Ajouter les titres et les axes
plt.title("Évolution de CozoRPG", fontsize=16)
plt.xlabel("#reified edges", fontsize=12)
plt.ylabel("Temps d'exécution (ms)", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Sauvegarder le graphique
plt.savefig("CozoRPG_RE.png")
plt.show()
